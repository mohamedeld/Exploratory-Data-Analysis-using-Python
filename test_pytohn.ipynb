# %%
cars = ["bmw", "audi", "toyota", "subaru"]
print(cars)
cars.sort()
# Out:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars
# Out:
# ['audi', 'bmw', 'subaru', 'toyota']

# %%
cars.sort(reverse=True)
print(cars)
# Out:
# ['toyota', 'subaru', 'bmw', 'audi']

# %%
cars = ["bmw", "audi", "toyota", "subaru"]
len(cars)
# Out:
# 4

# %%
values = ["first", "Second","third","fourth"]
for index in range(len(values)):
    value = values[index]
    print(index,value)
# Out:
# 0 first
# 1 Second
# 2 third
# 3 fourth

# %%
list(range(2,20,2))
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %%
players = ["mohamed", "ahmed", "ali", "hassan"]

print(players[1:3])
print(players[2:]) # list[start:end:step]
# Out:
# ['ahmed', 'ali']
# ['ali', 'hassan']

# %%
my_foods = ['pizza', 'falafel', 'carrot cake']

friend_foods = my_foods[:]

print(friend_foods)
# Out:
# ['pizza', 'falafel', 'carrot cake']

# %%
dimesions = (100,300)
print(dimesions)
# Out:
# (100, 300)

# %%
name = "mohamed"
name[0] = "s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 name = "mohamed"
# ----> 2 name[0] = "s"
#
# TypeError: 'str' object does not support item assignment

# %%
set1 = {1,2,2,4,5,6,5}
set1.update([44,55], {46,77})
set1.discard(5)
set1
# Out:
# {1, 2, 4, 6, 44, 46, 55, 77}

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}

print(A & B)
print(A.intersection(B))
print(B.intersection(A))
# Out:
# {4, 5}
# {4, 5}
# {4, 5}

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}

print(A - B)
print(A.difference(B))
print(B.difference(A))
# Out:
# {1, 2, 3}
# {1, 2, 3}
# {8, 6, 7}

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}

print(A ^ B)
print(A.symmetric_difference(B))
# Out:
# {1, 2, 3, 6, 7, 8}
# {1, 2, 3, 6, 7, 8}

# %%
human = {'height':180, 'weight':80, 'eye-color':'blue'} 
human.items()
human.keys()
human.values()
# Out:
# dict_values([180, 80, 'blue'])

# %%
new_set = set(human.values())
new_set
# Out:
# {180, 80, 'blue'}

# %%
'my {} is {}'.format('name', 'mohamed')
# Out:
# 'my name is mohamed'

# %%
'my {a} is {b}'.format(a='name', b='mohamed')
# Out:
# 'my name is mohamed'

# %%
'abc is {a[3]} def is {b[0]}'.format(a='Hello', b=["ahmed", "hassan"])
# Out:
# 'abc is l def is ahmed'

# %%
'the value of pi is: {0:.2f}'.format(3.14159265)
# Out:
# 'the value of pi is: 3.14'

# %%
name = "mohamed"
age = 26

text = f"my name is {name}, I am {age}"
text
# Out:
# 'my name is mohamed, I am 26'

# %%
f'{3.1452:.2f}'
# Out:
# '3.15'

# %%
from decimal import Decimal

# %%
f'{Decimal("10000000000000000000000000000000000.0"):.3f}'
# Out:
# '10000000000000000000000000000000000.000'

# %%
f'{123456.78:,.2f}'
# Out:
# '123,456.78'

# %%
text_list = ['chess', 'estimation', 'computers', 'reading']
','.join(text_list)
# Out:
# 'chess,estimation,computers,reading'

# %%
name = "Mohamed, elsayed, ali, mohamed"
name_list = name.split(", ")
name_list
# Out:
# ['Mohamed', 'elsayed', 'ali', 'mohamed']

# %%
hoppy = """
my name is 
mohamed elsayed
ali mohamed
"""
hoppy_split = hoppy.splitlines()
hoppy_split
# Out:
# ['', 'my name is ', 'mohamed elsayed', 'ali mohamed']

# %%
print("Amanda: welcome to cairo and also: welcome".partition(": "))
# Out:
# ('Amanda', ': ', 'welcome to cairo and also: welcome')

# %%
'-23'.isdigit()
# Out:
# False

# %%
'33'.isdecimal()
# Out:
# True

# %%
'A987'.isalnum()
# Out:
# True

# %%
file_path = "C:\\MyFolder\\MyFolder2\\MyFile.txt"
print(file_path)
# Out:
# C:\MyFolder\MyFolder2\MyFile.txt

# %%
file_path = r"C:\MyFolder\MyFolder2\MyFile.txt"
print(file_path)
# Out:
# C:\MyFolder\MyFolder2\MyFile.txt

# %%
food_dictionary = {
    "apple": "fruit",
    "carrot": "vegetable",
    "chicken": "meat",
    "rice": "grain",
    "milk": "dairy"
}
for counter, (index, value) in list(enumerate(food_dictionary.items())):
    print(counter ,index, value)
# Out:
# 0 apple fruit
# 1 carrot vegetable
# 2 chicken meat
# 3 rice grain
# 4 milk dairy

# %%
from collections import Counter

# %%
text = "my name is mohamed elsayed elrfaay"
counter = Counter(text.split())
print(counter)
# Out:
# Counter({'my': 1, 'name': 1, 'is': 1, 'mohamed': 1, 'elsayed': 1, 'elrfaay': 1})

# %%
x = 12
id(x)
# Out:
# 140729892988376

# %%
def cube(number):
    print('id number',id(number))
    return number ** 2;
cube(x)
# Out:
# id number 140729892988376
# 144

# %%
def cuber(x):
    return x ** 3

my_list = [10,20,30,40]
result = map(cuber, my_list)

print(list(result))
# Out:
# [1000, 8000, 27000, 64000]

# %%
f = lambda x: x ** 2
f(3)
# Out:
# 9

# %%
my_list = [2,3,4]
result = list(map(lambda a: a ** 2, my_list))
result
# Out:
# [4, 9, 16]

# %%
the_greats = ["mohamed elsayed", "amal elsayed", "elsayed ali"]
the_greats.sort(key= lambda name: name.split(' ')[-1])
the_greats
# Out:
# ['elsayed ali', 'mohamed elsayed', 'amal elsayed']

# %%
def myFunc(n):
    return lambda a: a * n

mydoubler = myFunc(2)
print(mydoubler(11))
# Out:
# 22

# %%
class Dog:
    def bark(self):
        print("haw haw")

# %%
dog1 = Dog()
dog1.bark()
# Out:
# haw haw

# %%
class Dog:
    def __init__(self,name):
        self.name = name
        
    def bark(self):
        print("haw haw")

# %%
dog2 = Dog("first")

# %%
dog2.name
# Out:
# 'first'

# %%
class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age
        
    def bark(self):
        print("haw haw")

    def set_age(self,age):
        self.age = age

    #getter 
    @property
    def name(self):
        return self._name

    @name.setter
    def name(self,name):
        if not name.isalpha():
            raise ValueError("Name must be alphabetical only")
        self._name = name

    @name.deleter
    def name(self):
        self.name = None

# %%
class Account:
    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
        self.__ssn = "123-456"

    def deposit(self, amount:'must be positive') -> 'insert money':
        if amount > 0:
            self.balance += balance
        else:
            raise ValueError("amout must be positive")

    def withDraw(self,amount):
        if amount > 0:
            self.balance -= amount

    def __repr__(self):
        return f'{self.name} currently has {self.balance} in his account'

    def __add__(self, other):
        return f'{self.name} and {other.name} both have a total of {self.balance + other.balance}'

# %%
acc2 = Account("Mohamed",22220)

# %%
acc2
# Out:
# Mohamed currently has 22220 in his account

# %%
acc3 = Account("ali", 333)

# %%
acc2 + acc3
# Out:
# 'Mohamed and ali both have a total of 22553'

# %%
class Employee:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname
        self.email = fname + "."+ lname + "@gmail.com"

# %%
class Teacher(Employee):
    def __init__(self,fname, lname):
        super().__init__(fname,lname)
        self.email = "t-" + fname + "."+ lname + "@gmail.com"

# %%
tr1 = Teacher('mohamed','elsayed')

# %%
tr1.email
# Out:
# 't-mohamed.elsayed@gmail.com'

# %%
# !cat pi_digits.txt
# Out:
# 124548
# 3.141598
# 6654782
# eeeeee
# errfdf

# %%
with open('pi_digits.txt') as file_object:
    contents = file_object.read()
print(contents.rstrip())
# Out:
# 124548
# 3.141598
# 6654782
# eeeeee
# errfdf

# %%
filename = "pi_digits.txt"
with open(filename) as file_object:
    lcounter = 1
    for line in file_object:
        print(lcounter,': ',line.rstrip())
        lcounter += 1
# Out:
# 1 :  124548
# 2 :  3.141598
# 3 :  6654782
# 4 :  eeeeee
# 5 :  errfdf

# %%
filename = "programming.txt"

with open(filename,'a') as file_object:
    file_object.write("I also love programming\n")
    file_object.write("And also love my mother\n")

# %%
# !cat programming.txt
# Out:
# I also love programming
# And also love my mother

# %%
import csv

# %%
# !cat people.csv
# Out:
# fname,lname,age,sex,country
# Mohamed,Ali,28,Male,Egypt
# Ahmed,Hassan,32,Male,Egypt
# Omar,Ibrahim,25,Male,Egypt
# Youssef,Mahmoud,30,Male,Egypt
# Adam,Khaled,22,Male,Jordan
# John,Smith,35,Male,USA
# Michael,Brown,29,Male,UK
# David,Wilson,41,Male,Canada
# Sarah,Johnson,27,Female,USA
# Emma,Williams,31,Female,UK
# Olivia,Davis,24,Female,Canada
# Mariam,Samir,26,Female,Egypt
# Nour,Fathy,33,Female,Egypt
# Lina,Ahmad,29,Female,Jordan
# Sofia,Garcia,36,Female,Spain
# Carlos,Martinez,38,Male,Spain
# Daniel,Lee,23,Male,South Korea
# Anna,Muller,34,Female,Germany
# James,Taylor,45,Male,Australia
# Emily,Anderson,28,Female,Australia

# %%
with open("people.csv",newline='') as csvFile:
    reader = csv.DictReader(csvFile)
    for row in reader:
        print(row['fname'], row['lname'])
# Out:
# Mohamed Ali
# Ahmed Hassan
# Omar Ibrahim
# Youssef Mahmoud
# Adam Khaled
# John Smith
# Michael Brown
# David Wilson
# Sarah Johnson
# Emma Williams
# Olivia Davis
# Mariam Samir
# Nour Fathy
# Lina Ahmad
# Sofia Garcia
# Carlos Martinez
# Daniel Lee
# Anna Muller
# James Taylor
# Emily Anderson

# %%
with open("people.csv","a",newline='') as csvFile:
    fieldnames = ['fname','lname','age','sex','country']
    writer = csv.DictWriter(csvFile,fieldnames)

    writer.writeheader()
    writer.writerow({
        "fname":"mohamed",
        "lname":"elrfaay",
        "age":26,
        "sex":"male",
        "country":"Egypt"
    })

# %%
# !cat people.csv
# Out:
# fname,lname,age,sex,country
# Mohamed,Ali,28,Male,Egypt
# Ahmed,Hassan,32,Male,Egypt
# Omar,Ibrahim,25,Male,Egypt
# Youssef,Mahmoud,30,Male,Egypt
# Adam,Khaled,22,Male,Jordan
# John,Smith,35,Male,USA
# Michael,Brown,29,Male,UK
# David,Wilson,41,Male,Canada
# Sarah,Johnson,27,Female,USA
# Emma,Williams,31,Female,UK
# Olivia,Davis,24,Female,Canada
# Mariam,Samir,26,Female,Egypt
# Nour,Fathy,33,Female,Egypt
# Lina,Ahmad,29,Female,Jordan
# Sofia,Garcia,36,Female,Spain
# Carlos,Martinez,38,Male,Spain
# Daniel,Lee,23,Male,South Korea
# Anna,Muller,34,Female,Germany
# James,Taylor,45,Male,Australia
# Emily,Anderson,28,Female,Australia
# fname,lname,age,sex,country
# mohamed,elrfaay,26,male,Egypt
# fname,lname,age,sex,country
# mohamed,elrfaay,26,male,Egypt

# %%
with open("people.csv",newline='') as csvFile:
    reader = csv.DictReader(csvFile,delimiter="\t")
    for row in reader:
        print(row['a'], row['lname'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       1 with open("people.csv",newline='') as csvFile:
#       2     reader = csv.DictReader(csvFile,delimiter="\t")
#       3     for row in reader:
# ----> 4         print(row['fname'], row['lname'])
#
# KeyError: 'fname'

# %%
import json

# %%
json.dumps(['foo',{'bar':('baz',None, 1.0,2)}])
# Out:
# '["foo", {"bar": ["baz", null, 1.0, 2]}]'

# %%
try:
    5 / 0
except Exception as e:
    print(dir(e))
    print(e.__class__)
    print(e.args[0])
# Out:
# ['__cause__', '__class__', '__context__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__suppress_context__', '__traceback__', 'add_note', 'args', 'with_traceback']
# <class 'ZeroDivisionError'>
# division by zero

# %%
try:
    5 / 0
except ZeroDivisionError:
    print("you can not divide by zero")
except: # default except
    print("something went wrong")
# Out:
# you can not divide by zero

# %%
try:
    5 / 0
except ZeroDivisionError:
    print("you can not divide by zero")
except: # default except
    print("something went wrong")
finally:
    print("will handled")
